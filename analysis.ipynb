# %%
import pandas as pd

# %%
df = pd.read_csv("../breast-cancer-analysis-/breast-cancer.csv",sep=",")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df["radius_mean"].describe()
# Out:
# count    569.000000
# mean      14.127292
# std        3.524049
# min        6.981000
# 25%       11.700000
# 50%       13.370000
# 75%       15.780000
# max       28.110000
# Name: radius_mean, dtype: float64

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# Método para verificar se existem valores NULOS na tabela.
#
# false = não contém valores nulos
#
# true = contém valores nulos

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Anáilse BloxPlot de todas as variáveis

# %%
df.boxplot(column=["radius_mean", "texture_mean"])
plt.show()

# %%
df.boxplot(column=["perimeter_mean", "area_mean"])
plt.show()

# %%
df.boxplot(column=["smoothness_mean","compactness_mean"])
plt.show()

# %%
df.boxplot(column=["concavity_mean","concave points_mean"])
plt.show()

# %%
df.boxplot(column=["concavity_mean","concave points_mean"])
plt.show()

# %%
df.boxplot(column=["symmetry_mean","fractal_dimension_mean"])
plt.show()

# %%
df.boxplot(column=["radius_se","texture_se"])
plt.show()

# %%
df.boxplot(column=["perimeter_se","area_se"])
plt.show()

# %%
df.boxplot(column=["smoothness_se","compactness_se"])
plt.show()

# %%
df.boxplot(column=["concavity_se","concave points_se"])
plt.show()

# %%
df.boxplot(column=["symmetry_se","fractal_dimension_se"])
plt.show()

# %%
df.boxplot(column=["radius_worst","texture_worst"])
plt.show()

# %%
df.boxplot(column=["perimeter_worst","area_worst"])
plt.show()

# %%
df.boxplot(column=["smoothness_worst","compactness_worst"])
plt.show()

# %%
df.boxplot(column=["concavity_worst","concave points_worst"])
plt.show()

# %%
df.boxplot(column=["symmetry_worst","fractal_dimension_worst"])
plt.show()

# %% [markdown]
# Conversão da variável resposta de String para Int

# %%
df['diagnosis'] = (df['diagnosis'] == 'M').astype(int)

# %%
corr = df.corr()

# %%
import matplotlib.pyplot as plt
import numpy as np

#y = pd.Series(df.iloc[:,1].values)
x = pd.Series(df.iloc[:,1].values)

x.plot.hist(grid=True, bins=20, rwidth=0.9,
            color='#607c8e')
plt.title('Frequência de Malignos "1" e Benignos "0"')
plt.xlabel('Tipo de nódulo')
plt.ylabel('Casos')
plt.grid(axis='x', alpha=0.75)
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr, cmap='mako_r',annot=True)
plt.show()
